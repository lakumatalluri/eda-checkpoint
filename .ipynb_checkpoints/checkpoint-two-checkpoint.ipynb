# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset:
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# create a dataframe coviddf (covid-19-country-statistics-dataset.csv)
coviddf=pd.read_csv('covid-19-country-statistics-dataset.csv')

# %%
# check if the dataframe is loaded correctly
coviddf.head(15)
# Out:
#                                                                    Number  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271     920,353
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977       57,410
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392      138,609
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800       38,084
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161      498,763
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273   11,889,802
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606      215,004
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463      136,174
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452       28,234
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208      205,914
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN                 NaN
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628       38,709
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813      891,874
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700       48,413
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514         1,866
#
#                                                               Country  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271   1,392
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977      NaN
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392      869
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800      NaN
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161      NaN
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273       48
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606      153
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463      104
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452      NaN
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208      NaN
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN             NaN
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628      231
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813       85
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700       61
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514        53
#
#                                                               Total Cases  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271     318,434
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977       31,938
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392      609,510
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800      457,786
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161      173,897
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273      268,261
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606      606,451
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463      427,548
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452      358,487
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208      156,601
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN             201,399
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628      295,918
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813      116,771
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700      437,737
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514       500,270
#
#                                                               New Cases  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271     3,464
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977        378
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392      2,538
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800      2,061
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161      3,257
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273        593
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606        671
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463      3,146
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452      3,240
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208      2,731
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN             1,194
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628      2,584
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813        436
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700        773
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514       1,336
#
#                                                                 Total Deaths  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271  1,176,758,558
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977     925,077,322
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392     271,490,188
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800     122,332,384
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161      63,776,166
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273      99,912,333
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606      15,804,065
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463     271,116,017
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452     522,526,476
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208     273,400,000
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN            162,743,369
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628     471,036,328
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813      85,826,548
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700      78,835,048
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514       25,984,435
#
#                                                                New Deaths  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271   3,514,755
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977      657,654
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392    4,139,547
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800    1,458,359
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161      296,146
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273      795,576
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606      307,892
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463    4,498,897
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452    7,628,357
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208    1,875,095
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN           1,902,052
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628   10,082,298
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813      867,342
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700    3,024,116
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514     1,509,718
#
#                                                               Total Recovered  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271     334,805,269
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977    1,406,631,776
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392       65,584,518
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800       83,883,596
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161      215,353,593
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273      125,584,838
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606       51,329,899
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463       60,262,770
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452       68,497,907
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208      145,805,947
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN              85,561,976
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628       46,719,142
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813       98,953,541
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700       26,068,792
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514        17,211,447
#
#                                                                     Active cases  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271      North America
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977                Asia
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392              Europe
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800              Europe
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161       South America
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273                Asia
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606                Asia
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463              Europe
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452              Europe
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208              Europe
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN                       Asia
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628              Europe
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813                Asia
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700   Australia/Oceania
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514               Europe
#
#                                                               Serious_Critical  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271                3
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977                31
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392                 2
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800                 2
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161                 6
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273                 4
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606                 2
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463                 2
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452                 3
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208                 6
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN                        5
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628                 3
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813                 9
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700                 2
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514                  2
#
#                                                               Total Cases Per 1m Pop  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271                    289
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977                   2,647
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392                     394
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800                     485
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161                     307
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273                   1,686
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606                   1,490
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463                     318
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452                     309
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208                     366
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN                            837
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628                     387
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813                   2,291
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700                   1,293
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514                      749
#
#                                                                Deaths Per 1m Pop  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271                0.0
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977                 2.0
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392                 0.0
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800                 1.0
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161                 3.0
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273                 1.0
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606                 3.0
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463                 0.0
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452                 0.0
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208                 1.0
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN                        1.0
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628                 0.0
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813                 1.0
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700                 0.0
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514                  1.0
#
#                                                                Total Tests  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271          5.0
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977           NaN
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392         101.0
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800           NaN
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161           NaN
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273          94.0
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606         278.0
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463           NaN
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452           NaN
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208          45.0
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN                  NaN
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628           NaN
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813          30.0
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700           NaN
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514            NaN
#
#                                                                Tests Per 1m Pop  \
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271               0.1
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977                NaN
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392                NaN
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800                NaN
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161                NaN
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273                0.2
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606                0.2
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463                NaN
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452                NaN
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208                0.2
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN                       NaN
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628                NaN
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813                NaN
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700                NaN
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514                 NaN
#
#                                                               Population
# 1  USA         106,613,321 +1,809  1,159,697 35.0 104,533,271      2,749
# 2  India       44,924,811  NaN     531,424   NaN  44,335,977          41
# 3  France      39,974,426  +6,609  166,425   NaN  39,669,392       2,113
# 4  Germany     38,400,766  NaN     172,882   NaN  38,189,800         454
# 5  Brazil      37,449,418  NaN     701,494   NaN  36,249,161       2,316
# 6  Japan       33,689,542  +11,764 74,467    24.0 21,725,273      94,675
# 7  S. Korea    31,129,070  +14,284 34,460    11.0 30,879,606       4,189
# 8  Italy       25,765,219  NaN     189,582   NaN  25,439,463       2,260
# 9  UK          24,555,629  NaN     221,943   NaN  24,305,452         412
# 10 Russia      22,833,330  +6,503  398,208   33.0 22,229,208       1,412
# 11 Turkey      17,232,066  NaN     102,174   NaN  NaN              4,024
# 12 Spain       13,825,052  NaN     120,715   NaN  13,665,628         829
# 13 Vietnam     11,554,875  +2,958  43,188    NaN  10,619,813       9,013
# 14 Australia   11,411,267  NaN     20,154    NaN  11,342,700       1,857
# 17 Netherlands 8,610,372   NaN     22,992    NaN  8,585,514          108

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
# how many columns and rows are in the dataframe
coviddf.shape
# rows 217 ,columns 14
# Out:
# (217, 14)

# %%
#what are the column names
coviddf.columns
# Index(['Number', 'Country', 'Total Cases', 'New Cases', 'Total Deaths',
#        'New Deaths', 'Total Recovered', 'Active cases', 'Serious_Critical',
#        'Total Cases Per 1m Pop', 'Deaths Per 1m Pop', 'Total Tests',
#        'Tests Per 1m Pop', 'Population'],
#       dtype='object')
# Out:
# Index(['Number', 'Country', 'Total Cases', 'New Cases', 'Total Deaths',
#        'New Deaths', 'Total Recovered', 'Active cases', 'Serious_Critical',
#        'Total Cases Per 1m Pop', 'Deaths Per 1m Pop', 'Total Tests',
#        'Tests Per 1m Pop', 'Population'],
#       dtype='object')

# %%
# information about the dataframe
coviddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 217 entries, (1, 'USA', '106,613,321', '+1,809', '1,159,697', 35.0, '104,533,271') to (231, 'China', '503,302', nan, '5,272', nan, '379,053')
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Number                  198 non-null    object
#  1   Country                 124 non-null    object
#  2   Total Cases             217 non-null    object
#  3   New Cases               214 non-null    object
#  4   Total Deaths            205 non-null    object
#  5   New Deaths              205 non-null    object
#  6   Total Recovered         217 non-null    object
#  7   Active cases            217 non-null    object
#  8   Serious_Critical        217 non-null    object
#  9   Total Cases Per 1m Pop  214 non-null    object
#  10  Deaths Per 1m Pop       205 non-null    float64
#  11  Total Tests             33 non-null     float64
#  12  Tests Per 1m Pop        15 non-null     float64
#  13  Population              217 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 72.7+ KB

# %%
#what is the destribution of the data columns with object datatype
coviddf.describe(include = ['object'])
# Out:
#        Number Country Total Cases New Cases Total Deaths New Deaths  \
# count     198     124         217       214          205        205
# unique    180      63         216       203          204        205
# top         6       1       5,041       101       78,646  3,514,755
# freq        5      11           2         3            2          1
#
#        Total Recovered Active cases Serious_Critical Total Cases Per 1m Pop  \
# count              217          217              217                    214
# unique             217            6               85                    208
# top        334,805,269       Africa                2                    394
# freq                 1           55               42                      2
#
#        Population
# count         217
# unique        193
# top             1
# freq            4

# %%
#what is the destribution of the data columns with float datatypes
coviddf.describe(include =['float'])
# Out:
#        Deaths Per 1m Pop  Total Tests  Tests Per 1m Pop
# count         205.000000    33.000000         15.000000
# mean            9.712195    33.356061          0.338667
# std            23.775092    52.608658          0.329737
# min             0.000000     0.060000          0.030000
# 25%             0.000000     4.000000          0.100000
# 50%             1.000000    13.000000          0.200000
# 75%             5.000000    45.000000          0.400000
# max           196.000000   278.000000          1.000000

# %%
coviddf.duplicated()
# Out:
# 1    USA           106,613,321  +1,809  1,159,697  35.0  104,533,271    False
# 2    India         44,924,811   NaN     531,424    NaN   44,335,977     False
# 3    France        39,974,426   +6,609  166,425    NaN   39,669,392     False
# 4    Germany       38,400,766   NaN     172,882    NaN   38,189,800     False
# 5    Brazil        37,449,418   NaN     701,494    NaN   36,249,161     False
#                                                                         ...
# 221  Tuvalu        2,805        NaN     NaN        NaN   NaN            False
# 222  Saint Helena  2,166        NaN     NaN        NaN   2              False
# 224  Montserrat    1,403        NaN     8          NaN   1,376          False
# 230  Tokelau       5            NaN     NaN        NaN   NaN            False
# 231  China         503,302      NaN     5,272      NaN   379,053        False
# Length: 217, dtype: bool

# %%
#finding the missing data values in each column
coviddf.isna().sum()
# Out:
# Number                     19
# Country                    93
# Total Cases                 0
# New Cases                   3
# Total Deaths               12
# New Deaths                 12
# Total Recovered             0
# Active cases                0
# Serious_Critical            0
# Total Cases Per 1m Pop      3
# Deaths Per 1m Pop          12
# Total Tests               184
# Tests Per 1m Pop          202
# Population                  0
# dtype: int64

# %%
# finding the percentage of data that is missing in each column
(coviddf.isnull().sum()/coviddf.shape[0])*100
# Out:
# Number                     8.755760
# Country                   42.857143
# Total Cases                0.000000
# New Cases                  1.382488
# Total Deaths               5.529954
# New Deaths                 5.529954
# Total Recovered            0.000000
# Active cases               0.000000
# Serious_Critical           0.000000
# Total Cases Per 1m Pop     1.382488
# Deaths Per 1m Pop          5.529954
# Total Tests               84.792627
# Tests Per 1m Pop          93.087558
# Population                 0.000000
# dtype: float64

# %%
list(coviddf.columns)
# Out:
# ['Number',
#  'Country',
#  'Total Cases',
#  'New Cases',
#  'Total Deaths',
#  'New Deaths',
#  'Total Recovered',
#  'Active cases',
#  'Serious_Critical',
#  'Total Cases Per 1m Pop',
#  'Deaths Per 1m Pop',
#  'Total Tests',
#  'Tests Per 1m Pop',
#  'Population']

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
coviddf[coviddf.columns[1:]] = coviddf[coviddf.columns[1:]].replace(',', '', regex=True).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 coviddf[coviddf.columns[1:]] = coviddf[coviddf.columns[1:]].replace(',', '', regex=True).astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: cannot convert float NaN to integer

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
# yes, the surprise was the ampount of missing country names which makes those rows unusable.
# 2. Do you have any concerns about your dataset?
# the inconsistency with the integer values that have been stored as string data is concerning as a lot of cleanup is necessary to make this data set work for analysis
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
# we need to remove 5 columns that are not necessary for the analysis,
# we need to drop the rows with missing data as it is not possible to replace considering each rows depicts one country we cannot use mean or any other aggregate function to replace the data
# we need to change the datatypes of columns with integer data that has been stored as string
# we need to change the coulumn names replacing the space character with underscore to make it easy to work on
